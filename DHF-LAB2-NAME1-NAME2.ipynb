# %%
import pandas as pd
import numpy as np
import os.path as osp
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import register_matplotlib_converters

# %%
register_matplotlib_converters()
sns.set()

# %% [markdown]
# ▶ All graphs should have a legend, a title, labeled x-axis and y-axis with units if applicable.
# ▶ Don’t plot log of (physical) quantities. Please use log scales instead.
# Don’t leave plot randomly in the notebook without context. Please indicate question
# numbers and comment on your results if necessary (especially if they are not what you
# were expecting).
#
# Do not use seaborn.
#
#
#
# TODO: adapt the legend with plt.legend, or put proper names during the computations.
# explain the graphs like in an article.

# %% [markdown]
# # Load data.

# %%
def load_data(dir: str) -> pd.DataFrame:
# Out:
#   Cell In[3], line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ## Load a sub-sample of the data.

# %%
df_q = pd.read_csv('./Data/RENA.PA/2017-01-02-RENA.PA-quotes.csv.gz', index_col = 0)

# %%
df_t = pd.read_csv('./Data/RENA.PA/2017-01-02-RENA.PA-trades.csv.gz', index_col = 0)

# %%
df_q.head()
# Out:
#                        ts  bid price  bq1  ask price  aq1    bp2  bq2    ap2  \
# 0 2017-01-02 09:01:18.813      84.19   35      84.31   38  84.18   35  84.34
# 1 2017-01-02 09:01:18.813      84.19   35      84.31  128  84.18   35  84.34
# 2 2017-01-02 09:01:19.893      84.19   35      84.31  193  84.18   35  84.34
# 3 2017-01-02 09:01:20.553      84.19   35      84.31  193  84.18   35  84.34
# 4 2017-01-02 09:01:20.553      84.19   35      84.31  193  84.18   35  84.33
#
#    aq2    bp3  ...  bq10   ap10  aq10  mid price  weighted mid price  spread  \
# 0   50  84.16  ...    55  84.44    55      84.25           84.247534    0.12
# 1   50  84.16  ...    55  84.44    55      84.25           84.215767    0.12
# 2   50  84.16  ...    55  84.44    55      84.25           84.208421    0.12
# 3   50  84.16  ...    55  84.44    55      84.25           84.208421    0.12
# 4   53  84.16  ...    55  84.42    75      84.25           84.208421    0.12
#
#    duration  weighted spread  imbalance  mid price move
# 0       NaN              NaN  -0.041096             NaN
# 1      0.00            0.000  -0.570552             0.0
# 2      1.08            1.296  -0.692982             0.0
# 3      0.66            0.792  -0.692982             0.0
# 4      0.00            0.000  -0.692982             0.0
#
# [5 rows x 48 columns]

# %%
df_t.head()
# Out:
#                         ts  price  volume
# 0  2017-01-02 09:01:15.893  84.31      90
# 1  2017-01-02 09:01:15.893  84.31      10
# 2  2017-01-02 09:01:18.813  84.31      12
# 3  2017-01-02 09:01:52.432  84.31      38
# 4  2017-01-02 09:01:52.452  84.31      62

# %% [markdown]
# # Multiple prices.
#
# Plot the bid price, ask price, mid price and weighted mid-price on a few
# minutes of your sample.

# %% [markdown]
# ## Compute the mid-price.

# %%
df_q['mid price'] = (df_q['bp1'] + df_q['ap1']) * .5

# %% [markdown]
# ## Compute the weighted mid-price.

# %%
df_q['weighted mid price'] = (df_q['bp1'] * df_q['aq1'] + df_q['ap1'] * df_q['bq1']) / (df_q['bq1'] + df_q['aq1'])

# %%
df_q['ask price'] = df_q['ap1']
df_q['bid price'] = df_q['bp1']
#df_q = df_q.rename(columns = {'ap1': 'ask price', 'bp1': 'bid price'})

# %% [markdown]
# ## Final plot.

# %%
df_q[:500].plot(x = 'ts', 
             y = ['bid price', 'ask price', 'mid price', 'weighted mid price'], 
             kind = 'line',
             title = 'Bid price and Ask price for each available observations.',
             grid = True,
             legend = True,
             xlabel = 'Available observations',
             ylabel = 'Price in Euros',
             rot = 90,
             )
# Out:
# <AxesSubplot: title={'center': 'Bid price and Ask price for each available observations.'}, xlabel='Available observations', ylabel='Price in Euros'>

# %% [markdown]
# # Spread distribution.

# %%
df_q['spread'] = df_q['ask price'] - df_q['bid price']

# %% [markdown]
# ## Plot in event time.

# %%
df_q.plot(y = ['spread'], 
             kind = 'hist',
             title = 'Empirical distribution of the spread in event time.',
             grid = True,
             legend = True,
             xlabel = 'Available observations',
             ylabel = 'Price in Euros',
             rot = 90,
             #bins = 20 #TODO change the bins.
             )
# Out:
# <AxesSubplot: title={'center': 'Empirical distribution of the spread in event time.'}, ylabel='Frequency'>

# %% [markdown]
# ## Plot in calendar time.

# %%
df_q.isna().any().any()
# Out:
# False

# %%
df_q.head()
# Out:
#                         ts  bid price  bq1  ask price  aq1    bp2  bq2    ap2  \
# 0  2017-01-02 09:01:18.813      84.19   35      84.31   38  84.18   35  84.34
# 1  2017-01-02 09:01:18.813      84.19   35      84.31  128  84.18   35  84.34
# 2  2017-01-02 09:01:19.893      84.19   35      84.31  193  84.18   35  84.34
# 3  2017-01-02 09:01:20.553      84.19   35      84.31  193  84.18   35  84.34
# 4  2017-01-02 09:01:20.553      84.19   35      84.31  193  84.18   35  84.33
#
#    aq2    bp3  ...  bq9    ap9  aq9   bp10  bq10   ap10  aq10  mid price  \
# 0   50  84.16  ...  700  84.42   75  84.09    55  84.44    55      84.25
# 1   50  84.16  ...  700  84.42   75  84.09    55  84.44    55      84.25
# 2   50  84.16  ...  700  84.42   75  84.09    55  84.44    55      84.25
# 3   50  84.16  ...  700  84.42   75  84.09    55  84.44    55      84.25
# 4   53  84.16  ...  700  84.41  700  84.09    55  84.42    75      84.25
#
#    weighted mid price  spread
# 0           84.247534    0.12
# 1           84.215767    0.12
# 2           84.208421    0.12
# 3           84.208421    0.12
# 4           84.208421    0.12
#
# [5 rows x 44 columns]

# %%
df_q.dtypes
# Out:
# ts                     object
# bid price             float64
# bq1                     int64
# ask price             float64
# aq1                     int64
# bp2                   float64
# bq2                     int64
# ap2                   float64
# aq2                     int64
# bp3                   float64
# bq3                     int64
# ap3                   float64
# aq3                     int64
# bp4                   float64
# bq4                     int64
# ap4                   float64
# aq4                     int64
# bp5                   float64
# bq5                     int64
# ap5                   float64
# aq5                     int64
# bp6                   float64
# bq6                     int64
# ap6                   float64
# aq6                     int64
# bp7                   float64
# bq7                     int64
# ap7                   float64
# aq7                     int64
# bp8                   float64
# bq8                     int64
# ap8                   float64
# aq8                     int64
# bp9                   float64
# bq9                     int64
# ap9                   float64
# aq9                     int64
# bp10                  float64
# bq10                    int64
# ap10                  float64
# aq10                    int64
# mid price             float64
# weighted mid price    float64
# spread                float64
# dtype: object

# %%
df_q['ts'] = pd.to_datetime(df_q['ts'])

# %%
df_q['duration'] = (df_q['ts'] - df_q['ts'].shift()).dt.total_seconds()

# %%
df_q['weighted spread'] = df_q['spread'] * df_q['duration'] * 10

# %%
df_q.plot(y = ['weighted spread'], 
             kind = 'hist',
             title = 'Empirical distribution of the spread in event time.',
             grid = True,
             legend = True,
             xlabel = 'Available observations',
             ylabel = 'Price in Euros',
             rot = 90,
             bins = 50 #TODO change the bins.
             )
# Out:
# <AxesSubplot: title={'center': 'Empirical distribution of the spread in event time.'}, ylabel='Frequency'>

# %% [markdown]
# # Imbalance and trading activity.

# %% [markdown]
# ## Compute the imbalance.

# %%
df_q['imbalance'] = (df_q['bq1'] - df_q['aq1']) / (df_q['bq1'] + df_q['aq1'])

# %% [markdown]
# ## Compute the mid-price move each times it moves in percentage.

# %%
df_q['mid price move'] = df_q['mid price'].pct_change()

# %% [markdown]
# # Plot

# %%
df_q.sort_values(by = 'imbalance', 
                 ascending=True, 
                 inplace=False, 
                 kind='heapsort').plot(x = 'imbalance', 
                                        y = ['mid price move'], 
                                        #use_index = False,
                                        kind = 'line',
                                        title = 'Mid price move as a function of the imbalance.',
                                        grid = True,
                                        legend = True,
                                        xlabel = 'Imbalance',
                                        ylabel = 'Price in Euros',
                                        rot = 90,
                                        )
# Out:
# <AxesSubplot: title={'center': 'Bid price and Ask price for each available observations.'}, xlabel='Available observations', ylabel='Price in Euros'>

# %% [markdown]
# # Auto correlations of the signs.

# %% [markdown]
# ## Compute the signs using a tick test.

# %%
df_t.head(20)
# Out:
#                          ts  price  volume   sign  temp sign     up   down
# 0   2017-01-02 09:01:15.893  84.31      90  False      False  False  False
# 1   2017-01-02 09:01:15.893  84.31      10  False      False  False  False
# 2   2017-01-02 09:01:18.813  84.31      12  False      False  False  False
# 3   2017-01-02 09:01:52.432  84.31      38  False      False  False  False
# 4   2017-01-02 09:01:52.452  84.31      62  False      False  False  False
# 5   2017-01-02 09:02:59.009  84.29      60  False      False  False   True
# 6   2017-01-02 09:02:59.009  84.29      64  False      False  False  False
# 7   2017-01-02 09:03:49.157  84.29      11  False      False  False  False
# 8   2017-01-02 09:05:11.114  84.23       1  False      False  False   True
# 9   2017-01-02 09:06:15.871  84.29      25   True       True   True  False
# 10  2017-01-02 09:06:15.871  84.29      32  False      False  False  False
# 11  2017-01-02 09:06:15.871  84.29      12  False      False  False  False
# 12  2017-01-02 09:06:15.871  84.30      66   True       True   True  False
# 13  2017-01-02 09:06:22.521  84.29      23  False      False  False   True
# 14  2017-01-02 09:06:47.949  84.34      20   True       True   True  False
# 15  2017-01-02 09:08:02.296  84.26      18  False      False  False   True
# 16  2017-01-02 09:08:02.296  84.26      15  False      False  False  False
# 17  2017-01-02 09:08:47.114  84.23      77  False      False  False   True
# 18  2017-01-02 09:08:47.124  84.23      73  False      False  False  False
# 19  2017-01-02 09:08:47.124  84.23      64  False      False  False  False

# %% [markdown]
# the 'up' column contains 'True' iff the price went up. The same goes for 'down'.

# %%
df_t['up'] = (df_t['price'].diff() > 0) 
df_t['down'] = (df_t['price'].diff() < 0)

# %%
df_t['lattest move'] =  'up' if df_t['up'] else ('down' if )

# %%
r = 2 if (5<4) else (5 if 3>6 else 7)
r
# Out:
# 7

# %%
def lattest_move()

# %%
df_t['sign'] = df_t.apply(, axis = 1)

# %% [markdown]
# # Plot distribution

# %% [markdown]
# We have ten levels.

# %%
i = 3

# %%
(df_q['bq' + str(i)] * df_q['bp' + str(i)]).sum() / df_q['bq' + str(i)].sum()
# Out:
# 85.15987856054726

# %% [markdown]
# TODO plot those bars next to each others.

# %% [markdown]
# ## Event time.

# %%
bid = [(df_q['bq' + str(i)] * df_q['bp' + str(i)]).sum() / df_q['bq' + str(i)].sum() for i in range(10)]
ask = [(df_q['aq' + str(i)] * df_q['ap' + str(i)]).sum() / df_q['aq' + str(i)].sum() for i in range(10)]

# %%
df_q.plot(y = ['spread'], 
             kind = 'hist',
             title = 'Empirical distribution of the spread in event time.',
             grid = True,
             legend = True,
             xlabel = 'Available observations',
             ylabel = 'Price in Euros',
             rot = 90,
             #bins = 20 #TODO change the bins.
             )

# %% [markdown]
# ## Calendar time.

# %%
bid = [(df_q['bq' + str(i)] * df_q['bp' + str(i)] * df_q['duration'] ).sum() /( df_q['bq' + str(i)] * df_q['duration'] ).sum() for i in range(10)]
ask = [(df_q['aq' + str(i)] * df_q['ap' + str(i)] * df_q['duration'] ).sum() / (df_q['aq' + str(i)] * df_q['duration'] ).sum() for i in range(10)]

# %%
df_q.head(20)
# Out:
#                         ts  bid price  bq1  ask price  aq1    bp2  bq2    ap2  \
# 0  2017-01-02 09:01:18.813      84.19   35      84.31   38  84.18   35  84.34
# 1  2017-01-02 09:01:18.813      84.19   35      84.31  128  84.18   35  84.34
# 2  2017-01-02 09:01:19.893      84.19   35      84.31  193  84.18   35  84.34
# 3  2017-01-02 09:01:20.553      84.19   35      84.31  193  84.18   35  84.34
# 4  2017-01-02 09:01:20.553      84.19   35      84.31  193  84.18   35  84.33
# 5  2017-01-02 09:01:20.553      84.19   35      84.31  193  84.18   35  84.33
# 6  2017-01-02 09:01:39.669      84.19   35      84.31  193  84.18   35  84.33
# 7  2017-01-02 09:01:39.713      84.19   35      84.31  128  84.18   35  84.33
# 8  2017-01-02 09:01:39.732      84.19   35      84.31  128  84.18  100  84.33
# 9  2017-01-02 09:01:39.732      84.19   35      84.31  128  84.18  100  84.34
# 10 2017-01-02 09:01:43.732      84.19   35      84.31  194  84.18  100  84.35
# 11 2017-01-02 09:01:43.732      84.19   35      84.31  194  84.18  100  84.35
# 12 2017-01-02 09:01:45.113      84.19   35      84.31  128  84.18  100  84.34
